# %%
# 1.Write a Python Program to Check if a Number is Positive, Negative or Zero?
# enter the number of choice
a=int(input("Enter Number  :"))

# if number is greater than zero
if a>0:

  print("{} is a Positive number".format(a))
# if number is less than zero
elif a<0:

  print("{} is a Negative number".format(a))
# if number is zero
else:

  print("Zero")

 
"""--------------------------------------------------------------------------------------------------------------""" 


#2. Write a Python Program to Check if a Number is Odd or Even?

# enter the number of choice
a=int(input("Enter Number  :"))

# checks if number is divisible by 2 
if a%2==0:

  print("{} is Even".format(a))

#  if number is not divisible by 2
else:

  print("{} is Odd".format(a))

 

"""--------------------------------------------------------------------------------------------------------------"""
    
#3. Write a Python Program to Check Leap Year?

 # enter the year of choice

a=int(input("Enter Year  :"))


# checks if year is divisible by 4

if a%4==0:

  print("{} is a leap year".format(a))

#  if year is not divisible by 4
else:

  print("{} is not a leap year".format(a))

"""---------------------------------------------------------------------------------------------------""" 

    
#4. Write a Python Program to Check Prime Number?


# enter the number of choice
a=int(input("Enter a number  :"))
# Assign 0 to  a variable 
count=0

for i in range(2,a):
# verifying if there are any numbers less than i that divide i
  if a%i==0:

    count+=1

    print("{} is not a prime number".format(a))
# if count =0 , we dont have any number less tha i that divide i, it means thats a prime number 
if count==0:

    print("{} is a prime number".format(a))

 

 

"""--------------------------------------------------------------------------------------------------------------"""
 

#5. Write a Python Program to Print all Prime Numbers in an Interval of 1-10000?

 
# giving the interval
for i in range(2,10000):
# intialising the count variable
  count=0
# verifying if there are any numbers less than i that divide i
  for j in range(2,i):

    if i%j==0:

      count+=1
# if count =0 , we dont have any number less tha i that divide i, it means thats a prime number 
  if count==0:
# Printing the prime number 
    print("{} is a prime".format(i))

# %% [markdown]
# ####
