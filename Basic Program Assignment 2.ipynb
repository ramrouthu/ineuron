# %%
# 1.Write a Python program to convert kilometers to miles?

# Enter the temperature in celcius
x=int(input("Enter number of kilometers: "))

# formula to convert from kms to miles
m=0.621371*x
# prining the converted value
print("{} kilometer/s is equal to {} miles".format(x,m))


"""----------------------------------------------------------------------------------------------------------"""

# 2. Write a Python program to convert Celsius to Fahrenheit?
# Enter the temperature in celcius

x=int(input("Enter Celcius temperature: "))

# formula to convert from celcius to farenheit
m=((9*x)/5)+32

# prining the converted value
print("{} celcius is equal to {} Farenheit".format(x,m))

 
"""----------------------------------------------------------------------------------------------------------"""    
    
# 3. Write a Python program to display calendar?

#importing calendar 
import calendar
# taking user inputs of month and year 
yy=int(input("Enter year: "))

mm=int(input("Enter month: "))
# printing the calendar

print(calendar.month(yy,mm))

"""----------------------------------------------------------------------------------------------------------"""

#4. Write a Python program to solve quadratic equation?
# importing math and cmath packages as square root ,complex number operations are involved

import cmath

import math

# taking user input--> coefficients of ax^2+bx+c=0 ,whose roots has to be found out
a=int(input("Enter coefficent of x^2:"))

b=int(input("Enter coefficient of x: "))

c=int(input("Enter constant: "))

#calculating discrimant squareroot(b^2-4ac)
# whether discrimant  contains imaginary values , we are checking through disc.img==0

disc=cmath.sqrt((b**2)-(4*a*c))

if disc.imag==0:
    

    # if disc is non-imaginary  we will find the  discriminant
    disc=math.sqrt((b**2)-(4*a*c))
# if discriminant is greater than 0 , we have real and different roots
  if  disc>0:

    root1=(-b+disc)/(2*a)

    root2=(-b-disc)/(2*a)

    print("Real roots exits and  are different:" ,root1,root2)
# if discriminant is = 0 , we have real and equal roots and print them
  else:

    root1=(-b)/(2*a)

    root2=(-b)/(2*a)

    print("Real roots exits and  are equal:" ,root1,root2)

    # if discrimant is lessthan 0 , we have imaginary roots and print them
else:

  root1=(-b+disc)/(2*a)

  root2=(-b-disc)/(2*a)

  print("Imaginary  roots exits" ,root1,root2)

"""----------------------------------------------------------------------------------------------------------"""

#5. Write a Python program to swap two variables without temp variable?

# taking user inputs and printing original numbers
a=int(input("Enter Number 1 :"))

b=int(input("Enter Number 2 :"))

print("Original numbers: a={},b={}".format(a,b))

# Assigning sum of user inputs to one number
a=a+b

# subtracting one variable from sum and assigning it to same variable
b=a-b
# subtracting one variable from sum and assigning it to same variable
a=a-b
#printing swapped variables
print("Swapped numbers: a={},b={}".format(a,b))
