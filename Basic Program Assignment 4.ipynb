# %%
#1.Write a Python Program to Find the Factorial of a Number?
# user input the number of his choice 
a=int(input("Enter the number you want factorial for :"))
# Assigning value 1 to factorial variable
factorial=1
# starting a loop from 1 to the (number+1) user entered
for i in range(1,a+1):
# User multiplying factorial by the i
    factorial=factorial*i
# printing the factorial value
print("The factorial of number is {}".format(factorial))

"""-------------------------------------------------------------------------------------------------------------"""
#2. Write a Python Program to Display the multiplication Table?
#Enter user choice of table number and table up to  
a=int(input("Enter the number you want table of :")) 
b=int(input("Enter the number up to which you want table for :"))
for j in range(1,b+1):
# printing the table
    print(a,"X",j,"=",a*j)

"""-------------------------------------------------------------------------------------------------------------"""
#3. Write a Python Program to Print the Fibonacci sequence?
# Assigning the values 0 , 1 to a,b
a,b,l=0,1,[]
# giving number of digits 
for i in range(30):
# appending 0 and 1 to the empty list 
    if(i<2):
        l.append(i)
# Assign sum of two previous numbers to s 
    else:
        s=a+b
# append the sum to list
        l.append(s)
# again assign  b and sum to a and b respectively  
        a=b
        b=s
#Printing the fibnocci series
print(l)

"""------------------------------------------------------------------------------------------------------------"""

#4. Write a Python Program to Check Armstrong Number?
# User enter the choice of his number 
a=input("Enter the number :")
#  intialising 0 to sum
sum=0
# since input returns string datatype , we are iterating through the string
for i in a:
# cubing each char in string, converting each  char to int
  sum=sum+(int(i)*int(i)*int(i))
# checking if sum is eqaul to the number we entered and printing accordingly
if sum==int(a):

  print("{} is a armstrong number".format(a))

else:

  print("{} is not an armstrong number".format(a))

"""----------------------------------------------------------------------------------------------------------"""
#5. Write a Python Program to Find Armstrong Number in an Interval?

# enter the start and end of interval

a=int(input("Enter the start of interval :"))

b=int(input("Enter the end of interval :"))

# create the empty list to add the armstrong number in the interval

l=[]

# iterating through the interval
for i in range(a,b+1):
# creating a varibale sum  with 0
  sum=0
# iterating through the number 
  for j in str(i):
# Adding  nth power of each digit of number to sum (n-number of digits number)  
    sum=sum+(pow(int(j),len(str(i))))
# if sum value is equal to digit , append to list 
    if sum==i:
        l.append(i)
# if list is empty , it means no armstrong in between the interval
if len(l)==0:
    print("No armstrong number in the given interval")
# if list is not empty ,print armstrong's in between the interval
else:
    l


"""-------------------------------------------------------------------------------------------------------------"""
#6. Write a Python Program to Find the Sum of Natural Numbers?
# Enter input of user choice
a=int(input("Enter the number :"))
# Assign zero to sum
sum=0
# iterate till the nth number (which we want sum up to)
for i in range(1,a+1):
# Add i to the sum 
  sum+=i
# Print the sum of natural numbers
print("sum of {} natural numbers is {}".format(a,sum))
